# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
import matplotlib.pyplot as plt
import sklearn

# %%
cars = pd.read_csv("data/CAR.csv")

# %%
cars = cars.replace('?', np.NaN)

# %%
cars = cars.drop([0, 1, 2])

# %%
cars['normalized-losses'] = cars['normalized-losses'].fillna(-1)
cars['normalized-losses'] = cars['normalized-losses'].astype(int)
cars['normalized-losses'] = cars['normalized-losses'].replace(-1, np.NaN)
cars['normalized-losses'] = cars.groupby(['make'])['normalized-losses'].transform(lambda x: x.fillna(x.mean()))

# %%
cars = cars.dropna(subset = ['normalized-losses'])

# %%
cars = cars.dropna(subset = ['price'])

# %%
cars['price'] = cars['price'].astype(float)

# %%
cars['bore'] = cars['bore'].fillna(-1)
cars['bore'] = cars['bore'].astype(float)
cars['bore'] = cars['bore'].replace(-1, np.NaN)

# %%
cars['stroke'] = cars['stroke'].astype(float)

# %%
cars['horsepower'] = cars['horsepower'].astype(float)

# %%
cars['peak-rpm'] = cars['peak-rpm'].astype(float)

# %%
cars.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-bae            float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
cars['bore'] = cars.groupby(['compression-ratio'])['bore'].transform(lambda x: x.fillna(x.mean()))
cars['stroke'] = cars.groupby(['compression-ratio'])['stroke'].transform(lambda x: x.fillna(x.mean()))

# %%
cars['horsepower'] = cars.groupby(['aspiration','num-of-cylinders'])['horsepower'].transform(lambda x: x.fillna(x.mean()))
cars['peak-rpm'] = cars.groupby(['aspiration','num-of-cylinders'])['peak-rpm'].transform(lambda x: x.fillna(x.mean()))

# %%
cars.iloc[133:140, 21:24]
# Out:
#      horsepower  peak-rpm  city-mpg
# 145       111.0    4800.0        24
# 146        82.0    4800.0        28
# 147        94.0    5200.0        25
# 148        82.0    4800.0        23
# 149       111.0    4800.0        23
# 150        62.0    4800.0        35
# 151        62.0    4800.0        31

# %%
cars['num-of-doors'] = cars['num-of-doors'].replace(np.NaN, 'four')

# %%
cars.iloc[55:70, 5:7]
# Out:
#    num-of-doors   body-style
# 63         four        sedan
# 64         four    hatchback
# 65         four        sedan
# 66         four        sedan
# 67         four        sedan
# 68         four        wagon
# 69          two      hardtop
# 70         four        sedan
# 71         four        sedan
# 72          two  convertible
# 73         four        sedan
# 74          two      hardtop
# 76          two    hatchback
# 77          two    hatchback
# 78          two    hatchback

# %%
cars.isna().any()[lambda x: x]
# Out:
# Series([], dtype: bool)

# %%
cars
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 3            2         164.000000        audi       gas        std
# 4            2         164.000000        audi       gas        std
# 5            2         161.000000        audi       gas        std
# 6            1         158.000000        audi       gas        std
# 7            1         161.000000        audi       gas        std
# 8            1         158.000000        audi       gas      turbo
# 10           2         192.000000         bmw       gas        std
# 11           0         192.000000         bmw       gas        std
# 12           0         188.000000         bmw       gas        std
# 13           0         188.000000         bmw       gas        std
# 14           1         190.000000         bmw       gas        std
# 15           0         190.000000         bmw       gas        std
# 16           0         190.000000         bmw       gas        std
# ...

# %%
cars['city-mpg'] = cars['city-mpg'].apply(lambda x: 235 / x )
cars['highway-mpg'] = cars['highway-mpg'].apply(lambda x: 235 / x )

# %%
cars['city-mpg']
# Out:
# 3       9.791667
# 4      13.055556
# 5      12.368421
# 6      12.368421
# 7      12.368421
# 8      13.823529
# 10     10.217391
# 11     10.217391
# 12     11.190476
# 13     11.190476
# 14     11.750000
# 15     14.687500
# 16     14.687500
# 17     15.666667
# 18      5.000000
# 19      6.184211
# 20      6.184211
# 21      6.351351
# 22      7.580645
# 23      9.791667
# 24      7.580645
# 25      7.580645
# 26      7.580645
# 27      9.791667
# 28      9.791667
# 29     12.368421
# 30      4.795918
# 31      7.580645
# 32      6.184211
# 33      7.833333
#          ...
# 175     8.703704
# 176     8.703704
# 177     8.703704
# 178    11.750000
# 179    12.368421
# 180    11.750000
# 181    12.368421
# 182     6.351351
# 183     8.703704
# 184     6.351351
# 185     8.703704
# 186     8.703704
# 187     6.351351
# 188     9.038462
# 189     9.791667
# 190     9.791667
# 191    12.368421
# 192     7.121212
# 193     9.400000
# 194    10.217391
# 195    10.217391
# ...

# %%
cars['highway-mpg']
# Out:
# 3       7.833333
# 4      10.681818
# 5       9.400000
# 6       9.400000
# 7       9.400000
# 8      11.750000
# 10      8.103448
# 11      8.103448
# 12      8.392857
# 13      8.392857
# 14      9.400000
# 15     10.681818
# 16     10.681818
# 17     11.750000
# 18      4.433962
# 19      5.465116
# 20      5.465116
# 21      5.731707
# 22      6.184211
# 23      7.833333
# 24      6.184211
# 25      6.184211
# 26      6.184211
# 27      7.833333
# 28      7.833333
# 29      9.791667
# 30      4.351852
# 31      6.184211
# 32      5.595238
# 33      6.911765
#          ...
# 175     7.343750
# 176     7.343750
# 177     7.343750
# 178     9.791667
# 179     9.791667
# 180     9.791667
# 181     9.791667
# 182     5.108696
# 183     6.911765
# 184     5.108696
# 185     6.911765
# 186     6.911765
# 187     5.595238
# 188     7.343750
# 189     8.103448
# 190     8.103448
# 191     9.791667
# 192     6.184211
# 193     7.580645
# 194     8.392857
# 195     8.392857
# ...

# %%
cars.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-bae', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
cars_length = cars['length']
cars_width = cars['width']
cars_height = cars['height']
sns.distplot(cars_height, bins = 20)
sns.distplot(cars_width, bins = 20)
sns.distplot(cars_length, bins = 20)
sns.set(rc={'figure.figsize':(10,40)})
# Out:
# /home/keulbunutu/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/keulbunutu/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/keulbunutu/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10,10))
cars_length = cars['length']
cars_width = cars['width']
cars_height = cars['height']
sns.kdeplot(cars_height)
sns.kdeplot(cars_width)
sns.kdeplot(cars_length)
sns.set(rc={'figure.figsize':(10,40)})

# %%
plt.figure(figsize=(10,10))
height_arr = np.array(cars['height'])
cars_height_norm = preprocessing.normalize([height_arr])
sns.distplot(cars_height_norm, bins = 20)
# Out:
# /home/keulbunutu/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10,10))

height_arr = np.array(cars['height'])
cars_height_norm = preprocessing.normalize([height_arr])
sns.distplot(cars_height_norm, bins = 20, hist=False, label="height")


width_arr = np.array(cars['width'])
cars_width_norm = preprocessing.normalize([width_arr])
sns.distplot(cars_width_norm, bins = 20, hist=False, label="width")


length_arr = np.array(cars['length'])
cars_length_norm = preprocessing.normalize([length_arr])
sns.distplot(cars_length_norm, bins = 20, hist=False, label="length")

# %%
plt.figure(figsize=(10,10))
length_arr = np.array(cars['length'])
cars_length_sigma = np.std(length_arr)
cars_length_mean = np.mean(length_arr)
cars_length_standardized = cars['length'].apply(lambda x: (x-cars_length_mean)/cars_length_sigma)
sns.distplot(cars_length_standardized,hist = False, label="length")

height_arr = np.array(cars['height'])
cars_height_sigma = np.std(height_arr)
cars_height_mean = np.mean(height_arr)
cars_height_standardized = cars['height'].apply(lambda x: (x-cars_height_mean)/cars_height_sigma)
sns.distplot(cars_height_standardized,hist = False, label="height")

width_arr = np.array(cars['width'])
cars_width_sigma = np.std(width_arr)
cars_width_mean = np.mean(width_arr)
cars_width_standardized = cars['width'].apply(lambda x: (x-cars_width_mean)/cars_width_sigma)
sns.distplot(cars_width_standardized,hist = False, label="width")

# %%
def standardize(serie):
    plt.figure(figsize=(10,10))
    arr = np.array(serie)
    sigma = np.std(arr)
    mean = np.mean(arr)
    serie_stand = serie.apply(lambda x: (x-mean)/sigma)
    return serie_stand
cars_length_stand = standardize(cars['length'])
cars_width_stand = standardize(cars['width'])
cars_height_stand = standardize(cars['height'])

sns.distplot(cars_length_stand,hist = False, label="length")
sns.distplot(cars_width_stand,hist = False, label="width")
sns.distplot(cars_height_stand,hist = False, label="height")

# %%
hp = pd.cut(np.array(cars['horsepower']),3, labels=["faible", "moyen", "fort"])
hp
# Out:
# [faible, faible, faible, faible, faible, ..., faible, moyen, moyen, faible, faible]
# Length: 193
# Categories (3, object): [faible < moyen < fort]

# %%
hp = cars['horsepower']
hp = pd.cut(hp,3,labels = ['faible','moyenne','forte'])
hp
# Out:
# 3       faible
# 4       faible
# 5       faible
# 6       faible
# 7       faible
# 8      moyenne
# 10      faible
# 11      faible
# 12     moyenne
# 13     moyenne
# 14     moyenne
# 15     moyenne
# 16     moyenne
# 17     moyenne
# 18      faible
# 19      faible
# 20      faible
# 21      faible
# 22      faible
# 23      faible
# 24      faible
# 25      faible
# 26      faible
# 27      faible
# 28      faible
# 29     moyenne
# 30      faible
# 31      faible
# 32      faible
# 33      faible
#         ...
# 175     faible
# 176     faible
# 177     faible
# 178    moyenne
# 179    moyenne
# 180    moyenne
# 181    moyenne
# 182     faible
# 183     faible
# 184     faible
# 185     faible
# 186     faible
# 187     faible
# 188     faible
# 189     faible
# 190     faible
# 191     faible
# 192     faible
# 193     faible
# 194     faible
# 195     faible
# 196     faible
# 197     faible
# 198    moyenne
# 199    moyenne
# 200     faible
# 201    moyenne
# 202    moyenne
# ...

# %%
cars['hp'] = hp

# %%
cars = cars[['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
       'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
       'wheel-bae', 'length', 'width', 'height', 'curb-weight', 'engine-type',
       'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
       'compression-ratio', 'peak-rpm', 'city-mpg',
       'highway-mpg', 'price', 'horsepower', 'hp']]

# %%
cars['fuel-type'] = pd.get_dummies(cars['fuel-type'])

# %%
cars['aspiration'] = pd.get_dummies(cars['aspiration'])

# %%
cars
# Out:
#      symboling  normalized-losses        make  fuel-type  aspiration  \
# 3            2         164.000000        audi          0           1
# 4            2         164.000000        audi          0           1
# 5            2         161.000000        audi          0           1
# 6            1         158.000000        audi          0           1
# 7            1         161.000000        audi          0           1
# 8            1         158.000000        audi          0           0
# 10           2         192.000000         bmw          0           1
# 11           0         192.000000         bmw          0           1
# 12           0         188.000000         bmw          0           1
# 13           0         188.000000         bmw          0           1
# 14           1         190.000000         bmw          0           1
# 15           0         190.000000         bmw          0           1
# 16           0         190.000000         bmw          0           1
# ...

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="body-style", y="price", data=cars)

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="normalized-losses", y="price", data=cars)

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="engine-size", y="price", data=cars)

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="city-mpg", y="price", data=cars)

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="horsepower", y="price", data=cars)

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="width", y="price", data=cars)

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="length", y="price", data=cars)

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="curb-weight", y="price", data=cars)

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="highway-mpg", y="price", data=cars)

# %%
ptn = cars[['engine-size', 'city-mpg', 'horsepower', 'width', 'length', 'curb-weight', 'highway-mpg', 'price']]

# %%
ptn.corr()
# Out:
#              engine-size  city-mpg  horsepower     width    length  \
# engine-size     1.000000  0.745676    0.828066  0.738257  0.687399
# city-mpg        0.745676  1.000000    0.891530  0.688346  0.664258
# horsepower      0.828066  0.891530    1.000000  0.621274  0.588581
# width           0.738257  0.688346    0.621274  1.000000  0.863937
# length          0.687399  0.664258    0.588581  0.863937  1.000000
# curb-weight     0.849780  0.786475    0.761013  0.876827  0.884463
# highway-mpg     0.784919  0.959134    0.843768  0.752283  0.713536
# price           0.874178  0.793081    0.815371  0.760351  0.696710
#
#              curb-weight  highway-mpg     price
# engine-size     0.849780     0.784919  0.874178
# city-mpg        0.786475     0.959134  0.793081
# horsepower      0.761013     0.843768  0.815371
# width           0.876827     0.752283  0.760351
# length          0.884463     0.713536  0.696710
# curb-weight     1.000000     0.837711  0.836184
# ...

# %%
#sklearn.linear_model.LinearRegression()
#fit(x,y)
#predict(x)

# %%
cc = cars[['engine-size','curb-weight','horsepower','city-mpg','width', 'length','highway-mpg','make', 'body-style','engine-type','num-of-cylinders','hp']]

# %%
cc.corr()
# Out:
#              engine-size  curb-weight  horsepower  city-mpg     width  \
# engine-size     1.000000     0.849780    0.828066  0.745676  0.738257
# curb-weight     0.849780     1.000000    0.761013  0.786475  0.876827
# horsepower      0.828066     0.761013    1.000000  0.891530  0.621274
# city-mpg        0.745676     0.786475    0.891530  1.000000  0.688346
# width           0.738257     0.876827    0.621274  0.688346  1.000000
# length          0.687399     0.884463    0.588581  0.664258  0.863937
# highway-mpg     0.784919     0.837711    0.843768  0.959134  0.752283
#
#                length  highway-mpg
# engine-size  0.687399     0.784919
# curb-weight  0.884463     0.837711
# horsepower   0.588581     0.843768
# city-mpg     0.664258     0.959134
# width        0.863937     0.752283
# length       1.000000     0.713536
# highway-mpg  0.713536     1.000000

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()

x = cc[['engine-size']]

y = cc[['horsepower']]

lm.fit(x, y).coef_
# Out:
# ------------------------------------------------------------------
# NameError                        Traceback (most recent call last)
# <ipython-input-2-6db1f81d567e> in <module>()
#       3 lm = LinearRegression()
#       4
# ----> 5 x = cc[['engine-size']]
#       6
#       7 y = cc[['horsepower']]
#
# NameError: name 'cc' is not defined

# %%
lm.predict(x)
# Out:
# array([[ 89.8771944 ],
#        [109.70431928],
#        [109.70431928],
#        [109.70431928],
#        [109.70431928],
#        [106.03262949],
#        [ 89.14285645],
#        [ 89.14285645],
#        [130.26578212],
#        [130.26578212],
#        [130.26578212],
#        [163.31099025],
#        [163.31099025],
#        [163.31099025],
#        [ 54.6289724 ],
#        [ 75.92477319],
#        [ 75.92477319],
#        [ 75.92477319],
#        [ 75.92477319],
#        [ 81.79947686],
#        [ 75.92477319],
#        [ 75.92477319],
#        [ 75.92477319],
#        [ 81.79947686],
#        [ 99.42358786],
#        [124.39107845],
#        [ 77.39344911],
#        [ 77.39344911],
#        [ 67.84705565],
#        [ 77.39344911],
#        [ 77.39344911],
#        [ 77.39344911],
#        [ 77.39344911],
#        [ 90.61153236],
#        [ 90.61153236],
#        [ 90.61153236],
#        [ 90.61153236],
#        [ 90.61153236],
#        [ 90.61153236],
#        [199.29355022],
# ...

# %%
plt.figure(figsize=(10,10))
lm.fit(cc[['horsepower']],cars['price'])
lm.coef_
lm.intercept_
lm.score(cc[['horsepower']],cars['price'])
lm.predict(cc[['horsepower']])
sns.residplot(cc[['horsepower']],cars['price'])

# %%
plt.figure(figsize=(5,5))
sns.residplot(cc[['engine-size']], cars['price'])
plt.show()
plt.figure(figsize=(5,5))
sns.residplot(cc[['horsepower']], cars['price'])
plt.show()
plt.figure(figsize=(5,5))
sns.residplot(cc[['highway-mpg']], cars['price'])
plt.show()
plt.figure(figsize=(5,5))
sns.residplot(cc[['city-mpg']], cars['price'])
plt.show()
plt.figure(figsize=(5,5))
sns.residplot(cc[['curb-weight']], cars['price'])
plt.show()
plt.figure(figsize=(5,5))
sns.residplot(cc[['width']], cars['price'])
plt.show()
plt.figure(figsize=(5,5))
sns.residplot(cc[['length']], cars['price'])
plt.show()

# %%
lm.predict(x)
# Out:
# array([14308.98154027, 19045.91273207, 19045.91273207, 19045.91273207,
#        19045.91273207, 18168.70325211, 14133.53964427, 14133.53964427,
#        23958.28581987, 23958.28581987, 23958.28581987, 31853.17113955,
#        31853.17113955, 31853.17113955,  5887.77053261, 10975.5855164 ,
#        10975.5855164 , 10975.5855164 , 10975.5855164 , 12379.12068435,
#        10975.5855164 , 10975.5855164 , 10975.5855164 , 12379.12068435,
#        16589.72618817, 22554.75065193, 11326.46930839, 11326.46930839,
#         9045.72466048, 11326.46930839, 11326.46930839, 11326.46930839,
#        11326.46930839, 14484.42343626, 14484.42343626, 14484.42343626,
#        14484.42343626, 14484.42343626, 14484.42343626, 40449.8240432 ,
#        40449.8240432 , 52379.87297071, 11151.0274124 , 11151.0274124 ,
#        11151.0274124 , 11151.0274124 , 11151.0274124 ,  7466.74759655,
#         7466.74759655,  7466.74759655,  9221.16655647, 16589.72618817,
# ...

# %%
lm.score(x, y)
# Out:
# -252652.39644656156

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(x, y)  
mean_squared_error(x, y, multioutput='raw_values')
# Out:
# array([1134.24352332])
