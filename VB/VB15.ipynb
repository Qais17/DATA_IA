# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
from pandas.tools.plotting import table
import matplotlib.cbook as cbook
vv17 = pd.read_excel('data/re17pro.xls')
vv17
# Out:
#                    DEPARTEMENTS  Nb déclarations prod   \
# 0                        01 AIN                    284
# 1                      02 AISNE                    818
# 2                     03 ALLIER                    109
# 3   04 ALPES DE HAUTES-PROVENCE                     72
# 4               05 HAUTES-ALPES                     94
# 5            06 ALPES-MARITIMES                     24
# 6                    07 ARDECHE                   1610
# 7                     09 ARIEGE                     25
# 8                       10 AUBE                   2605
# 9                       11 AUDE                   5282
# 10                   12 AVEYRON                    132
# 11          13 BOUCHES-DU-RHONE                   1151
# 12                  14 CALVADOS                      1
# 13                    15 CANTAL                      6
# 14                  16 CHARENTE                   2729
# 15         17 CHARENTE-MARITIME                   3719
# 16                      18 CHER                    538
# 17                   19 CORREZE                    166
# 18                 21 COTE-D'OR                   1451
# 19                  24 DORDOGNE                   1062
# 20                     25 DOUBS                     68
# 21                     26 DROME                   1590
# 22              28 EURE-ET-LOIR                      0
# 23              2A CORSE-DU-SUD                     47
# 24               2B HAUTE-CORSE                    229
# 25                      30 GARD                   3915
# 26             31 HAUTE-GARONNE                    166
# 27                      32 GERS                   1154
# 28                   33 GIRONDE                   6452
# 29                   34 HERAULT                   8575
# ..                          ...                    ...
# 49                   57 MOSELLE                     33
# 50                    58 NIEVRE                    254
# 51                      59 NORD                      1
# 52                      60 OISE                      1
# 53             62 PAS-DE-CALAIS                      1
# 54               63 PUY-DE-DOME                    299
# 55      64 PYRENEES-ATLANTIQUES                    588
# 56           65 HAUTES-PYRENEES                    113
# 57       66 PYRENEES-ORIENTALES                   2509
# 58                  67 BAS-RHIN                   1729
# 59                 68 HAUT-RHIN                   2230
# 60                     69 RHONE                   2411
# 61               70 HAUTE-SAONE                     94
# 62            71 SAONE-ET-LOIRE                   1825
# 63                    72 SARTHE                     64
# 64                    73 SAVOIE                    420
# 65              74 HAUTE-SAVOIE                     82
# 66            76 SEINE-MARITIME                      1
# 67            77 SEINE-ET-MARNE                      9
# 68               79 DEUX-SEVRES                    338
# 69                      81 TARN                    557
# 70           82 TARN-ET-GARONNE                    288
# 71                       83 VAR                   3356
# 72                  84 VAUCLUSE                   3829
# 73                    85 VENDEE                    632
# 74                    86 VIENNE                    667
# 75              87 HAUTE-VIENNE                      2
# 76                    88 VOSGES                     54
# 77                     89 YONNE                    860
# 78     90 TERRITOIRE-DE-BELFORT                      1
#
#     Sup totale vignes (ha)  Sup vignes AOP (ha)  \
# 0                 749.5860             537.0579
# 1                2523.6857            2519.2927
# 2                 610.2514             557.7564
# 3                 700.5272             293.9354
# 4                 114.6767               0.0000
# 5                  83.9044              51.8575
# 6               10273.6524            2689.9748
# 7                  67.4368               0.0000
# 8                7171.9611            7165.4513
# 9               64535.0459           19754.9406
# 10                388.5481             286.8094
# 11              11192.9550            7621.7267
# 12                  4.9000               0.0000
# 13                  9.2560               1.5800
# 14              39336.9834             107.3924
# 15              39102.3830             924.2218
# 16               4225.6395            4147.6367
# 17                 93.9789               3.6373
# 18               9464.9361            9378.7337
# 19              11311.3471           10522.6503
# 20                 25.9804               0.0000
# 21              15864.8640           13621.2860
# 22                  0.0000               0.0000
# 23                876.9278             713.4527
# 24               5000.3120            2092.9941
# 25              52604.6921           19476.0785
# 26               1359.1508             770.6950
# 27              18476.8786            1718.1243
# 28             114554.3782          112772.3086
# 29              80840.5254           16450.4456
# ..                     ...                  ...
# 49                 77.8164              50.2718
# 50               1527.6356            1401.4261
# 51                  1.1600               0.0000
# 52                  0.2525               0.0000
# 53                  0.3000               0.0000
# 54                438.4123             274.0979
# 55               2499.7498            2348.9349
# 56                250.5922             208.6516
# 57              21437.6506           14844.9191
# 58               6698.0237            6677.0034
# 59               8986.9572            8969.3266
# 60              16237.0183           15802.3539
# 61                103.9686               0.0000
# 62              12990.8598           12873.9170
# 63                197.9071             144.1313
# 64               1849.6304            1667.1880
# 65                239.9497             143.9015
# 66                  0.6000               0.0000
# 67                 26.6895              26.6895
# 68                810.4565             692.4428
# 69               6560.6776            3177.8210
# 70               1473.9493             712.8333
# 71              28110.8926           22147.8519
# 72              45748.9434           35735.3777
# 73                949.6227             501.5323
# 74               1186.8673             552.2656
# 75                  7.1386               0.0000
# 76                  7.2618               0.0000
# 77               7683.4878            7636.5554
# 78                  0.2500               0.0000
#
#     Sup vignes cognac - armagniac (ha)  Sup vignes IGP (ha)  \
# 0                               0.0000              20.5849
# 1                               0.0000               0.0000
# 2                               0.0000               7.1575
# 3                               0.0000             356.9192
# 4                               0.0000             105.3222
# 5                               0.0000              30.5922
# 6                               0.0000            7088.9027
# 7                               0.0000              60.3022
# 8                               0.0000               0.0000
# 9                               0.0000           41715.1604
# 10                              0.0000              53.9237
# 11                              0.0000            3389.5225
# 12                              0.0000               4.9000
# 13                              0.0000               7.2226
# 14                          38398.1884             362.1839
# 15                          36158.3685            1165.9661
# 16                              0.0000              40.7495
# 17                              0.0000              62.8847
# 18                              0.0000              29.8079
# 19                             18.3990             304.6016
# 20                              0.0000              10.7209
# 21                              0.0000            2010.9265
# 22                              0.0000               0.0000
# 23                              0.0000              77.1126
# 24                              0.0000            2711.7247
# 25                              0.0000           30917.0788
# 26                              0.0000             471.3540
# 27                           1357.8986           12061.6841
# 28                              0.0000             192.6849
# 29                              0.0000           60371.7851
# ..                                 ...                  ...
# 49                              0.0000               0.0000
# 50                              0.0000              97.0379
# 51                              0.0000               0.0000
# 52                              0.0000               0.0000
# 53                              0.0000               0.0000
# 54                              0.0000              78.7800
# 55                              0.0000              64.6424
# 56                              0.0000              21.9061
# 57                              0.0000            5774.1043
# 58                              0.0000               0.0000
# 59                              0.0000               0.0000
# 60                              0.0000             122.8235
# 61                              0.0000              78.4948
# 62                              0.0000              15.0264
# 63                              0.0000               6.8357
# 64                              0.0000              99.3589
# 65                              0.0000              12.8700
# 66                              0.0000               0.0000
# 67                              0.0000               0.0000
# 68                              0.0000              33.5338
# 69                              0.0000            2533.0438
# 70                              0.0000             532.8808
# 72            20142.63            3931.00                        0.00
# 73             2007.12            3254.77                        0.00
# 74             3561.98             709.25                        0.00
# 75                0.80               0.00                        0.00
# 76              181.00               0.00                        0.00
# 77              511.91             182.82                        0.00
# 78               20.00               0.00                        0.00
#
#     Prod commercialisable (hl)  Autres production (hl)
# 0                     29429.25                  186.12
# 1                    151224.19                 1341.88
# 2                     14783.62                  282.28
# 3                     32118.58                  934.01
# 4                      2063.21                  131.46
# 5                      2054.05                   40.00
# 6                    389257.84                 7346.63
# 7                      1319.90                   30.21
# 8                    485952.56                 7408.31
# 9                   3093722.02                53372.40
# 10                     4716.69                  151.54
# 11                   516954.91                18490.51
# 12                      116.65                    0.00
# 13                      101.85                    3.70
# 14                  3018900.86                 3316.71
# 15                  3830758.77                 9586.67
# 16                   234903.76                 1087.37
# 17                     1091.37                   10.04
# 18                   460596.83                 7711.14
# 19                   300026.60                 6160.47
# 20                      619.50                   34.53
# 21                   568663.69                13762.15
# 22                        0.00                    0.00
# 23                    26718.22                  745.53
# 24                   281301.31                 6215.86
# 25                  2515072.32                68538.32
# 26                    46550.38                 1302.12
# 27                  1592374.22                69611.85
# 28                  3573449.06                64812.28
# 29                  3930368.86               106111.31
# ..                         ...                     ...
# 49                     2927.77                   20.26
# 50                    73216.75                  786.14
# 51                       39.75                    0.00
# 52                       11.50                    0.00
# 53                        7.00                    0.00
# 54                    10171.57                  125.15
# 55                   101575.87                 1106.88
# 56                    11017.50                  220.50
# 57                   656138.70                16672.98
# 58                   432839.32                 7015.94
# 59                   479292.55                 5659.81
# 60                   637590.67                38389.88
# 61                     2852.35                   30.00
# 62                   700909.27                20240.35
# 63                     6159.45                  197.03
# 64                    96427.32                 1054.48
# 65                     8365.83                   25.52
# 66                       15.70                    0.00
# 67                     1356.60                    4.79
# 68                    40540.50                  519.80
# 69                   356615.06                 7308.11
# 70                    60088.56                 1550.27
# 71                  1157279.19                54210.44
# 72                  1504177.90                38258.68
# 73                    43745.71                 1227.67
# 74                    49942.96                  501.97
# 75                       30.90                    4.00
# 76                      181.80                    0.00
# 77                   345123.07                 3111.12
# 78                       20.00                    0.00
#
# [79 rows x 20 columns]

# %%
plt.pie(
    # using data total)arrests
    vv17['Qt AOP Blanc (hl)'],
    # with the labels being officer names
    labels=vv17['DEPARTEMENTS'],
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()

# %%
plt.pie(
    # using data total)arrests
    vv17['Qt AOP Blanc (hl)'],
    # with the labels being officer names
    labels=vv17['DEPARTEMENTS'],
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()

# %%
da = vv17.set_index('DEPARTEMENTS').loc[:,['Qt AOP Blanc (hl)']]
da
# Out:
#                              Qt AOP Blanc (hl)
# DEPARTEMENTS
# 01 AIN                                 9457.75
# 02 AISNE                             151065.59
# 03 ALLIER                              3591.34
# 04 ALPES DE HAUTES-PROVENCE            1251.21
# 05 HAUTES-ALPES                           0.00
# 06 ALPES-MARITIMES                      467.83
# 07 ARDECHE                             8964.98
# 09 ARIEGE                                 0.00
# 10 AUBE                              485247.66
# 11 AUDE                               98544.66
# 12 AVEYRON                              132.50
# 13 BOUCHES-DU-RHONE                   17690.16
# 14 CALVADOS                               0.00
# 15 CANTAL                                 8.50
# 16 CHARENTE                            2482.43
# 17 CHARENTE-MARITIME                  25338.49
# 18 CHER                              186352.49
# 19 CORREZE                                0.00
# 21 COTE-D'OR                         167416.04
# 24 DORDOGNE                          118571.30
# 25 DOUBS                                  0.00
# 26 DROME                              64466.45
# 28 EURE-ET-LOIR                           0.00
# 2A CORSE-DU-SUD                        4006.28
# 2B HAUTE-CORSE                        12010.14
# 30 GARD                               47729.11
# 31 HAUTE-GARONNE                          0.00
# 32 GERS                               19455.25
# 33 GIRONDE                           371880.35
# 34 HERAULT                           112647.36
# ...                                        ...
# 57 MOSELLE                             1050.20
# 58 NIEVRE                             67634.47
# 59 NORD                                   0.00
# 60 OISE                                   0.00
# 62 PAS-DE-CALAIS                          0.00
# 63 PUY-DE-DOME                          624.30
# 64 PYRENEES-ATLANTIQUES               54278.79
# 65 HAUTES-PYRENEES                     1163.77
# 66 PYRENEES-ORIENTALES                95569.95
# 67 BAS-RHIN                          403543.53
# 68 HAUT-RHIN                         440170.27
# 69 RHONE                              72634.92
# 70 HAUTE-SAONE                            0.00
# 71 SAONE-ET-LOIRE                    495104.67
# 72 SARTHE                              2978.37
# 73 SAVOIE                             61452.27
# 74 HAUTE-SAVOIE                        4291.78
# 76 SEINE-MARITIME                         0.00
# 77 SEINE-ET-MARNE                      1356.60
# 79 DEUX-SEVRES                        13042.60
# 81 TARN                               39525.98
# 82 TARN-ET-GARONNE                        0.00
# 83 VAR                                35663.19
# 84 VAUCLUSE                           77433.85
# 85 VENDEE                              6328.90
# 86 VIENNE                             16605.60
# 87 HAUTE-VIENNE                           0.00
# 88 VOSGES                                 0.00
# 89 YONNE                             309440.75
# 90 TERRITOIRE-DE-BELFORT                  0.00
#
# [79 rows x 1 columns]

# %%
da.describe()
# Out:
#        Qt AOP Blanc (hl)
# count       7.900000e+01
# mean        8.297423e+04
# std         2.033640e+05
# min         0.000000e+00
# 25%         0.000000e+00
# 50%         6.314150e+03
# 75%         7.013470e+04
# max         1.529661e+06

# %%
da.idxmax()
# Meme fait surprenant qu'en 2016, en 2017 aussi ont se retrouve avec une production en hectolitre du cognac et de 
# l'armagniac plus elever en CHARENTE-MARITIME alors qu'en CHARENTE il y'a plus d'hectar exploitable
# Out:
# Qt AOP Blanc (hl)    51 MARNE
# dtype: object

# %%
listeA = da.sort_values(['Qt AOP Blanc (hl)'], ascending=False)
ListeA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-de6d8395f6ee> in <module>()
#       1 listeA = da.sort_values(['Qt AOP Blanc (hl)'], ascending=False)
# ----> 2 ListeA
#
# NameError: name 'ListeA' is not defined

# %%
classement = da.sort_values(['Qt AOP Blanc (hl)'], ascending=False)
classement
# Out:
#                              Qt AOP Blanc (hl)
# DEPARTEMENTS
# 51 MARNE                            1529661.25
# 71 SAONE-ET-LOIRE                    495104.67
# 10 AUBE                              485247.66
# 68 HAUT-RHIN                         440170.27
# 67 BAS-RHIN                          403543.53
# 33 GIRONDE                           371880.35
# 89 YONNE                             309440.75
# 49 MAINE-ET-LOIRE                    274025.26
# 44 LOIRE-ATLANTIQUE                  273990.26
# 18 CHER                              186352.49
# 21 COTE-D'OR                         167416.04
# 37 INDRE-ET-LOIRE                    167228.41
# 02 AISNE                             151065.59
# 24 DORDOGNE                          118571.30
# 41 LOIR-ET-CHER                      116064.29
# 34 HERAULT                           112647.36
# 11 AUDE                               98544.66
# 66 PYRENEES-ORIENTALES                95569.95
# 84 VAUCLUSE                           77433.85
# 69 RHONE                              72634.92
# 58 NIEVRE                             67634.47
# 26 DROME                              64466.45
# 73 SAVOIE                             61452.27
# 64 PYRENEES-ATLANTIQUES               54278.79
# 30 GARD                               47729.11
# 81 TARN                               39525.98
# 83 VAR                                35663.19
# 39 JURA                               31560.44
# 47 LOT-ET-GARONNE                     25902.88
# 17 CHARENTE-MARITIME                  25338.49
# ...                                        ...
# 45 LOIRET                              1262.17
# 04 ALPES DE HAUTES-PROVENCE            1251.21
# 65 HAUTES-PYRENEES                     1163.77
# 57 MOSELLE                             1050.20
# 63 PUY-DE-DOME                          624.30
# 54 MEURTHE-ET-MOSELLE                   557.98
# 06 ALPES-MARITIMES                      467.83
# 12 AVEYRON                              132.50
# 15 CANTAL                                 8.50
# 76 SEINE-MARITIME                         0.00
# 88 VOSGES                                 0.00
# 87 HAUTE-VIENNE                           0.00
# 05 HAUTES-ALPES                           0.00
# 09 ARIEGE                                 0.00
# 82 TARN-ET-GARONNE                        0.00
# 14 CALVADOS                               0.00
# 19 CORREZE                                0.00
# 28 EURE-ET-LOIR                           0.00
# 25 DOUBS                                  0.00
# 59 NORD                                   0.00
# 31 HAUTE-GARONNE                          0.00
# 43 HAUTE-LOIRE                            0.00
# 70 HAUTE-SAONE                            0.00
# 46 LOT                                    0.00
# 48 LOZERE                                 0.00
# 53 MAYENNE                                0.00
# 55 MEUSE                                  0.00
# 62 PAS-DE-CALAIS                          0.00
# 60 OISE                                   0.00
# 90 TERRITOIRE-DE-BELFORT                  0.00
#
# [79 rows x 1 columns]

# %%
top = classement.iloc[:10]
top
# Out:
#                      Qt AOP Blanc (hl)
# DEPARTEMENTS
# 51 MARNE                    1529661.25
# 71 SAONE-ET-LOIRE            495104.67
# 10 AUBE                      485247.66
# 68 HAUT-RHIN                 440170.27
# 67 BAS-RHIN                  403543.53
# 33 GIRONDE                   371880.35
# 89 YONNE                     309440.75
# 49 MAINE-ET-LOIRE            274025.26
# 44 LOIRE-ATLANTIQUE          273990.26
# 18 CHER                      186352.49

# %%
autre = classement.iloc[11:90]
autre
# Out:
#                              Qt AOP Blanc (hl)
# DEPARTEMENTS
# 37 INDRE-ET-LOIRE                    167228.41
# 02 AISNE                             151065.59
# 24 DORDOGNE                          118571.30
# 41 LOIR-ET-CHER                      116064.29
# 34 HERAULT                           112647.36
# 11 AUDE                               98544.66
# 66 PYRENEES-ORIENTALES                95569.95
# 84 VAUCLUSE                           77433.85
# 69 RHONE                              72634.92
# 58 NIEVRE                             67634.47
# 26 DROME                              64466.45
# 73 SAVOIE                             61452.27
# 64 PYRENEES-ATLANTIQUES               54278.79
# 30 GARD                               47729.11
# 81 TARN                               39525.98
# 83 VAR                                35663.19
# 39 JURA                               31560.44
# 47 LOT-ET-GARONNE                     25902.88
# 17 CHARENTE-MARITIME                  25338.49
# 32 GERS                               19455.25
# 13 BOUCHES-DU-RHONE                   17690.16
# 86 VIENNE                             16605.60
# 79 DEUX-SEVRES                        13042.60
# 2B HAUTE-CORSE                        12010.14
# 01 AIN                                 9457.75
# 07 ARDECHE                             8964.98
# 36 INDRE                               7870.11
# 85 VENDEE                              6328.90
# 38 ISERE                               6314.15
# 42 LOIRE                               5633.19
# ...                                        ...
# 45 LOIRET                              1262.17
# 04 ALPES DE HAUTES-PROVENCE            1251.21
# 65 HAUTES-PYRENEES                     1163.77
# 57 MOSELLE                             1050.20
# 63 PUY-DE-DOME                          624.30
# 54 MEURTHE-ET-MOSELLE                   557.98
# 06 ALPES-MARITIMES                      467.83
# 12 AVEYRON                              132.50
# 15 CANTAL                                 8.50
# 76 SEINE-MARITIME                         0.00
# 88 VOSGES                                 0.00
# 87 HAUTE-VIENNE                           0.00
# 05 HAUTES-ALPES                           0.00
# 09 ARIEGE                                 0.00
# 82 TARN-ET-GARONNE                        0.00
# 14 CALVADOS                               0.00
# 19 CORREZE                                0.00
# 28 EURE-ET-LOIR                           0.00
# 25 DOUBS                                  0.00
# 59 NORD                                   0.00
# 31 HAUTE-GARONNE                          0.00
# 43 HAUTE-LOIRE                            0.00
# 70 HAUTE-SAONE                            0.00
# 46 LOT                                    0.00
# 48 LOZERE                                 0.00
# 53 MAYENNE                                0.00
# 55 MEUSE                                  0.00
# 62 PAS-DE-CALAIS                          0.00
# 60 OISE                                   0.00
# 90 TERRITOIRE-DE-BELFORT                  0.00
#
# [68 rows x 1 columns]

# %%
autres = autre.sum()
autres
# Out:
# Qt AOP Blanc (hl)    1618131.55
# dtype: float64

# %%
top = classement.iloc[:10]
top = top.reset_index()
perfect = top.append(autres.T, ignore_index=True).fillna("AUTRE").set_index("DEPARTEMENTS")
perfect
# Out:
#                      Qt AOP Blanc (hl)
# DEPARTEMENTS
# 51 MARNE                    1529661.25
# 71 SAONE-ET-LOIRE            495104.67
# 10 AUBE                      485247.66
# 68 HAUT-RHIN                 440170.27
# 67 BAS-RHIN                  403543.53
# 33 GIRONDE                   371880.35
# 89 YONNE                     309440.75
# 49 MAINE-ET-LOIRE            274025.26
# 44 LOIRE-ATLANTIQUE          273990.26
# 18 CHER                      186352.49
# AUTRE                       1618131.55

# %%
plt.pie(
    # using data total)arrests
    perfect['Qt AOP Blanc (hl)'],
    # with the labels being officer names
    labels=perfect.index,
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
from matplotlib
def svg_parse(path):
    commands = {'M': (Path.MOVETO,),
                'L': (Path.LINETO,),
                'Q': (Path.CURVE3,)*2,
                'C': (Path.CURVE4,)*3,
                'Z': (Path.CLOSEPOLY,)}
    path_re = re.compile(r'([MLHVCSQTAZ])([^MLHVCSQTAZ]+)', re.IGNORECASE)
    float_re = re.compile(r'(?:[\s,]*)([+-]?\d+(?:\.\d+)?)')
    vertices = []
    codes = []
    last = (0, 0)
    for cmd, values in path_re.findall(path):
        points = [float(v) for v in float_re.findall(values)]
        points = np.array(points).reshape((len(points)//2, 2))
        if cmd.islower():
            points += last
        cmd = cmd.capitalize()
        last = points[-1]
        codes.extend(commands[cmd])
        vertices.extend(points.tolist())
    return codes, vertices

# SVG to matplotlib
codes, verts = svg_parse(firefox)
verts = np.array(verts)
path = Path(verts, codes)

# Make upside down
verts[:, 1] *= -1
xmin, xmax = verts[:, 0].min()-1, verts[:, 0].max()+1
ymin, ymax = verts[:, 1].min()-1, verts[:, 1].max()+1

fig = plt.figure(figsize=(5, 5))
ax = fig.add_axes([0.0, 0.0, 1.0, 1.0], frameon=False, aspect=1)

# White outline (width = 6)
patch = patches.PathPatch(path, facecolor='None', edgecolor='w', lw=6)
ax.add_patch(patch)

# Actual shape with black outline
patch = patches.PathPatch(path, facecolor='orange', edgecolor='k', lw=2)
ax.add_patch(patch)

# Centering
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)

# No ticks
ax.set_xticks([])
ax.set_yticks([])

# Display
plt.show()

# %%
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, PathPatch
from matplotlib.path import Path
from matplotlib.transforms import Affine2D
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


r = np.random.rand(50)
t = np.random.rand(50) * np.pi * 2.0
x = r * np.cos(t)
y = r * np.sin(t)

fig, ax = plt.subplots(figsize=(6, 6))
circle = Circle((0, 0), 1, facecolor='none',
                edgecolor=(0, 0.8, 0.8), linewidth=3, alpha=0.5)
ax.add_patch(circle)

im = plt.imshow(np.random.random((100, 100)),
                origin='lower', cmap=cm.winter,
                interpolation='spline36',
                extent=([-1, 1, -1, 1]))
im.set_clip_path(circle)

plt.plot(x, y, 'o', color=(0.9, 0.9, 1.0), alpha=0.8)

# Dolphin from OpenClipart library by Andy Fitzsimon
#       <cc:License rdf:about="http://web.resource.org/cc/PublicDomain">
#         <cc:permits rdf:resource="http://web.resource.org/cc/Reproduction"/>
#         <cc:permits rdf:resource="http://web.resource.org/cc/Distribution"/>
#         <cc:permits rdf:resource="http://web.resource.org/cc/DerivativeWorks"/>
#       </cc:License>

dolphin = """
M -0.59739425,160.18173 C -0.62740401,160.18885 -0.57867129,160.11183
-0.57867129,160.11183 C -0.57867129,160.11183 -0.5438361,159.89315
-0.39514638,159.81496 C -0.24645668,159.73678 -0.18316813,159.71981
-0.18316813,159.71981 C -0.18316813,159.71981 -0.10322971,159.58124
-0.057804323,159.58725 C -0.029723983,159.58913 -0.061841603,159.60356
-0.071265813,159.62815 C -0.080250183,159.65325 -0.082918513,159.70554
-0.061841203,159.71248 C -0.040763903,159.7194 -0.0066711426,159.71091
0.077336307,159.73612 C 0.16879567,159.76377 0.28380306,159.86448
0.31516668,159.91533 C 0.3465303,159.96618 0.5011127,160.1771
0.5011127,160.1771 C 0.63668998,160.19238 0.67763022,160.31259
0.66556395,160.32668 C 0.65339985,160.34212 0.66350443,160.33642
0.64907098,160.33088 C 0.63463742,160.32533 0.61309688,160.297
0.5789627,160.29339 C 0.54348657,160.28968 0.52329693,160.27674
0.50728856,160.27737 C 0.49060916,160.27795 0.48965803,160.31565
0.46114204,160.33673 C 0.43329696,160.35786 0.4570711,160.39871
0.43309565,160.40685 C 0.4105108,160.41442 0.39416631,160.33027
0.3954995,160.2935 C 0.39683269,160.25672 0.43807996,160.21522
0.44567915,160.19734 C 0.45327833,160.17946 0.27946869,159.9424
-0.061852613,159.99845 C -0.083965233,160.0427 -0.26176109,160.06683
-0.26176109,160.06683 C -0.30127962,160.07028 -0.21167141,160.09731
-0.24649368,160.1011 C -0.32642366,160.11569 -0.34521187,160.06895
-0.40622293,160.0819 C -0.467234,160.09485 -0.56738444,160.17461
-0.59739425,160.18173
"""

vertices = []
codes = []
parts = dolphin.split()
i = 0
code_map = {
    'M': (Path.MOVETO, 1),
    'C': (Path.CURVE4, 3),
    'L': (Path.LINETO, 1)}

while i < len(parts):
    code = parts[i]
    path_code, npoints = code_map[code]
    codes.extend([path_code] * npoints)
    vertices.extend([[float(x) for x in y.split(',')] for y in
                     parts[i + 1:i + npoints + 1]])
    i += npoints + 1
vertices = np.array(vertices, float)
vertices[:, 1] -= 160

dolphin_path = Path(vertices, codes)
dolphin_patch = PathPatch(dolphin_path, facecolor=(0.6, 0.6, 0.6),
                          edgecolor=(0.0, 0.0, 0.0))
ax.add_patch(dolphin_patch)

vertices = Affine2D().rotate_deg(60).transform(vertices)
dolphin_path2 = Path(vertices, codes)
dolphin_patch2 = PathPatch(dolphin_path2, facecolor=(0.5, 0.5, 0.5),
                           edgecolor=(0.0, 0.0, 0.0))
ax.add_patch(dolphin_patch2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D



fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface('DEPARTEMENTS', 'Qt AOP Blanc (hl)', 'Qt AOP Blanc (hl)', 'Qt IGP Blanc (hl)', rstride=1, cstride=1, cmap=cm.viridis)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-18f23d0b4d8d> in <module>()
#       8 fig = plt.figure()
#       9 ax = Axes3D(fig)
# ---> 10 ax.plot_surface('DEPARTEMENTS', 'Qt AOP Blanc (hl)', 'Qt AOP Blanc (hl)', 'Qt IGP Blanc (hl)', rstride=1, cstride=1, cmap=cm.viridis)
#      11
#      12 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1633         had_data = self.has_data()
#    1634
# -> 1635         if Z.ndim != 2:
#    1636             raise ValueError("Argument Z must be 2-dimensional.")
#    1637         # TODO: Support masked arrays
#
# AttributeError: 'str' object has no attribute 'ndim'
