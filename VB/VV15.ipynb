# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
from pandas.tools.plotting import table
import matplotlib.cbook as cbook
vv15 = pd.read_excel('data/re15pro.xls')
vv15
# Out:
#          DEPARTEMENTS  Nb déclarations prod   Sup totale vignes (ha)  \
# 0              01 AIN                    382                758.4526
# 1            02 AISNE                    804               2441.2928
# 2           03 ALLIER                    209                647.2769
# 3     04 ALPES-HTE-PR                     78                674.1128
# 4     05 ALPES-HAUTES                    110                115.6571
# 5       06 ALPES-Mmes                     31                 85.9950
# 6          07 ARDECHE                   1825              10320.8559
# 7         08 ARDENNES                      2                  0.1020
# 8           09 ARIEGE                     42                 67.4625
# 9             10 AUBE                   2647               6967.7343
# 10            11 AUDE                   5535              67810.3697
# 11         12 AVEYRON                    150                403.6896
# 12    13 BOUCHES-DU-R                   1166              10150.5962
# ...

# %%
vv15.set_index('DEPARTEMENTS')
# Out:
#                    Nb déclarations prod   Sup totale vignes (ha)  \
# DEPARTEMENTS
# 01 AIN                               382                758.4526
# 02 AISNE                             804               2441.2928
# 03 ALLIER                            209                647.2769
# 04 ALPES-HTE-PR                       78                674.1128
# 05 ALPES-HAUTES                      110                115.6571
# 06 ALPES-Mmes                         31                 85.9950
# 07 ARDECHE                          1825              10320.8559
# 08 ARDENNES                            2                  0.1020
# 09 ARIEGE                             42                 67.4625
# 10 AUBE                             2647               6967.7343
# 11 AUDE                             5535              67810.3697
# 12 AVEYRON                           150                403.6896
# 13 BOUCHES-DU-R                     1166              10150.5962
# ...

# %%
len(vv15.columns)
# Out:
# 21

# %%
hectar = vv15.set_index('DEPARTEMENTS').loc[:,['Sup totale vignes (ha)','Sup vignes AOP (ha)','Sup vignes cognac - armagniac (ha)','Sup vignes IGP (ha)','Sup vignes VSIG (ha)']]
hectar
# je regroupe tout les type d'hectar different pour savoir qu'elle region a le plus a le plus d'hectar pour
# savoir si cela impact la prodution en hectolitre
# Out:
#                    Sup totale vignes (ha)  Sup vignes AOP (ha)  \
# DEPARTEMENTS
# 01 AIN                           758.4526             551.8399
# 02 AISNE                        2441.2928            2435.8592
# 03 ALLIER                        647.2769             553.2800
# 04 ALPES-HTE-PR                  674.1128             282.2810
# 05 ALPES-HAUTES                  115.6571               0.0000
# 06 ALPES-Mmes                     85.9950              53.8371
# 07 ARDECHE                     10320.8559            2665.3086
# 08 ARDENNES                        0.1020               0.0000
# 09 ARIEGE                         67.4625               0.0000
# 10 AUBE                         6967.7343            6951.3677
# 11 AUDE                        67810.3697           19683.4989
# 12 AVEYRON                       403.6896             279.9360
# 13 BOUCHES-DU-R                10150.5962            6670.3495
# 14 CALVADOS                        4.9000               0.0000
# ...

# %%
h['hhh'] = vv15['Sup totale vignes (ha)'] + vv15['Sup vignes AOP (ha)'] + vv15['Sup vignes cognac - armagniac (ha)'] + vv15['Sup vignes IGP (ha)'] + vv15['Sup vignes VSIG (ha)'] 
h
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-31c416fc29fd> in <module>()
# ----> 1 h['hhh'] = vv15['Sup totale vignes (ha)'] + vv15['Sup vignes AOP (ha)'] + vv15['Sup vignes cognac - armagniac (ha)'] + vv15['Sup vignes IGP (ha)'] + vv15['Sup vignes VSIG (ha)']
#       2 h
#
# NameError: name 'h' is not defined

# %%
plt.pie(
    # using data total)arrests
    vv15['Sup vignes cognac - armagniac (ha)'],
    # with the labels being officer names
    labels=vv15['DEPARTEMENTS'],
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()
# ont remarque que pour Sup vignes cognac - armagniac (ha) c'est les regions de CHARENTE 
# ET CHARENTE-MAR qui ont le plus d'hectar

# %%
plt.pie(
    # using data total)arrests
    vv15['Sup vignes AOP (ha)'],
    # with the labels being officer names
    labels=vv15['DEPARTEMENTS'],
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()
# ont remarque que pour Sup vignes AOP (ha) c'est les regions de GIRONDE(Loin devant)
# ET VAUCLUSE qui ont le plus d'hectar

# %%
plt.pie(
    # using data total)arrests
    vv15['Sup vignes IGP (ha)'],
    # with the labels being officer names
    labels=vv15['DEPARTEMENTS'],
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()
# ont remarque que pour Sup vignes IGP (ha) c'est les regions de L'HERAULT ET L'AUDE qui ont le plus d'hectar

# %%
plt.pie(
    # using data total)arrests
    vv15['Sup vignes VSIG (ha)'],
    # with the labels being officer names
    labels=vv15['DEPARTEMENTS'],
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()

# ont remarque que pour Sup vignes VSIG (ha) c'est les regions de L'HERAULT ET L'AUDE qui ont le plus d'hectar

# %%
plt.pie(
    # using data total)arrests
    vv15['Sup totale vignes (ha)'],
    # with the labels being officer names
    labels=vv15['DEPARTEMENTS'],
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()
# et je vien de remarquer que mon analyse statistique qui devait repondre a qu'elle regions a le plus d'hectar 
# par rapport au hectolitre ecouler est deja effectuer dans Sup totale vignes (ha) ...
# tant pis je vait contimuer a jouer le jeu.. 
# ont remarque que pour Sup totale vignes (ha) c'est la region de LA GIRONDE qui possede le plus d'hectar tout 
# alcool confondu suivi par L'HERAULT ET L'AUDE

# %%
vv15.loc[vv15.DEPARTEMENTS == vv15.DEPARTEMENTS['11 AUDE'] vv15.DEPARTEMENTS['16 CHARENTE'] vv15.DEPARTEMENTS['17 CHARENTE-MAR'] vv15.DEPARTEMENTS['33 GIRONDE'] vv15.DEPARTEMENTS['34 HERAULT']]
# je n'ai pas trouver la bonne syntaxe pour regrouper les regions avec le plus d'hectar
# Out:
#   File "<ipython-input-11-ddaad4257d6e>", line 1
#     vv15.loc[vv15.DEPARTEMENTS == vv15.DEPARTEMENTS['11 AUDE'] vv15.DEPARTEMENTS['16 CHARENTE'] vv15.DEPARTEMENTS['17 CHARENTE-MAR'] vv15.DEPARTEMENTS['33 GIRONDE'] vv15.DEPARTEMENTS['34 HERAULT']]
#                                                                   ^
# SyntaxError: invalid syntax

# %%
ca = vv15.set_index('Qt Cognac ou Armagnec (hl)').loc[:,['Sup vignes cognac - armagniac (ha)']]
ca
# j'ai essayer de faire une correlation entre Qt Cognac ou Armagnec (hl) et  Sup vignes cognac - armagniac (ha)
# car ca me sembler pertinenent, sans succes malheureusement
# Out:
#                             Sup vignes cognac - armagniac (ha)
# Qt Cognac ou Armagnec (hl)
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# 0.00                                                    0.0000
# ...

# %%
da = vv15.set_index('DEPARTEMENTS').loc[:,['Sup vignes cognac - armagniac (ha)', 'Qt Cognac ou Armagnec (hl)']]
da
# je vais donc mettre en corelation Sup vignes cognac - armagniac (ha) et Qt Cognac ou Armagnec (hl)
# pour savoir si plus ont a d'hectar, plus ont produit, jai pris comme exemple le gognac et l'armaniac
# car pas beaucoup de region en produisent, donc moin de donnee pour plus de lisibilite
# Out:
#                    Sup vignes cognac - armagniac (ha)  \
# DEPARTEMENTS
# 01 AIN                                         0.0000
# 02 AISNE                                       0.0000
# 03 ALLIER                                      0.0000
# 04 ALPES-HTE-PR                                0.0000
# 05 ALPES-HAUTES                                0.0000
# 06 ALPES-Mmes                                  0.0000
# 07 ARDECHE                                     0.0000
# 08 ARDENNES                                    0.0000
# 09 ARIEGE                                      0.0000
# 10 AUBE                                        0.0000
# 11 AUDE                                        0.0000
# 12 AVEYRON                                     0.0000
# 13 BOUCHES-DU-R                                0.0000
# 14 CALVADOS                                    0.0000
# 15 CANTAL                                      0.0000
# 16 CHARENTE                                37838.3640
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(t, s)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('About as simple as it gets, folks')
plt.grid(True)
plt.savefig("test.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d52d0ca824f9> in <module>()
#       2 import numpy as np
#       3
# ----> 4 plt.plot(t, s)
#       5
#       6 plt.xlabel('time (s)')
#
# NameError: name 't' is not defined

# %%
da.describe()
# Out:
#        Sup vignes cognac - armagniac (ha)  Qt Cognac ou Armagnec (hl)
# count                           79.000000                7.900000e+01
# mean                           954.376933                1.199868e+05
# std                           5807.481859                7.340509e+05
# min                              0.000000                0.000000e+00
# 25%                              0.000000                0.000000e+00
# 50%                              0.000000                0.000000e+00
# 75%                              0.000000                0.000000e+00
# max                          37838.364000                4.697139e+06

# %%
da.idxmax()
# ont en deduit que la region Charente est la region avec le plus d'hectar pour cultiver les vignes dedier
# a la production de cognac et d'armgniac et cela ce ressent sur la quantiter de gognac et d'armagniac produit 
# en Charente qui est la plus eveler de toutes les regions
# Out:
# Sup vignes cognac - armagniac (ha)    16 CHARENTE
# Qt Cognac ou Armagnec (hl)            16 CHARENTE
# dtype: object

# %%
#vv15.plot.scatter(x='Sup totale vignes (ha)', y='Sup vignes VSIG (ha)', 
                 # w='Sup vignes AOP (ha)', u='Sup vignes cognac - armagniac (ha)')

# %%
classement = da.sort_values(['Sup vignes cognac - armagniac (ha)', 'Qt Cognac ou Armagnec (hl)'], ascending=False)
classement
# Out:
#                    Sup vignes cognac - armagniac (ha)  \
# DEPARTEMENTS
# 16 CHARENTE                                37838.3640
# 17 CHARENTE-MAR                            35614.0841
# 32 GERS                                     1557.6914
# 40 LANDES                                    343.1748
# 47 LOT-ET-GAR                                 28.0906
# 24 DORDOGNE                                   14.3728
# 01 AIN                                         0.0000
# 02 AISNE                                       0.0000
# 03 ALLIER                                      0.0000
# 04 ALPES-HTE-PR                                0.0000
# 05 ALPES-HAUTES                                0.0000
# 06 ALPES-Mmes                                  0.0000
# 07 ARDECHE                                     0.0000
# 08 ARDENNES                                    0.0000
# 09 ARIEGE                                      0.0000
# 10 AUBE                                        0.0000
# ...

# %%
top = classement.iloc[:2]
top
# Out:
#                  Sup vignes cognac - armagniac (ha)  \
# DEPARTEMENTS
# 16 CHARENTE                              37838.3640
# 17 CHARENTE-MAR                          35614.0841
#
#                  Qt Cognac ou Armagnec (hl)
# DEPARTEMENTS
# 16 CHARENTE                      4697139.32
# 17 CHARENTE-MAR                  4591089.05

# %%
autre = classement.iloc[3:90]
autre
# Out:
#                    Sup vignes cognac - armagniac (ha)  \
# DEPARTEMENTS
# 40 LANDES                                    343.1748
# 47 LOT-ET-GAR                                 28.0906
# 24 DORDOGNE                                   14.3728
# 01 AIN                                         0.0000
# 02 AISNE                                       0.0000
# 03 ALLIER                                      0.0000
# 04 ALPES-HTE-PR                                0.0000
# 05 ALPES-HAUTES                                0.0000
# 06 ALPES-Mmes                                  0.0000
# 07 ARDECHE                                     0.0000
# 08 ARDENNES                                    0.0000
# 09 ARIEGE                                      0.0000
# 10 AUBE                                        0.0000
# 11 AUDE                                        0.0000
# 12 AVEYRON                                     0.0000
# 13 BOUCHES-DU-R                                0.0000
# ...

# %%
autres = autre.sum()
autres
# Out:
# Sup vignes cognac - armagniac (ha)      385.6382
# Qt Cognac ou Armagnec (hl)            36119.6600
# dtype: float64

# %%
cognac = pd.concat([top, autres], axis=0)
cognac
# Out:
# /home/keulbunutu/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/api.py:107: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
#                                     Sup vignes cognac - armagniac (ha)  \
# 16 CHARENTE                                                 37838.3640
# 17 CHARENTE-MAR                                             35614.0841
# Sup vignes cognac - armagniac (ha)                                 NaN
# Qt Cognac ou Armagnec (hl)                                         NaN
#
#                                     Qt Cognac ou Armagnec (hl)           0
# 16 CHARENTE                                         4697139.32         NaN
# 17 CHARENTE-MAR                                     4591089.05         NaN
# Sup vignes cognac - armagniac (ha)                         NaN    385.6382
# Qt Cognac ou Armagnec (hl)                                 NaN  36119.6600

# %%
autre['toto'] = autre[["Sup vignes cognac - armagniac (ha)", "Qt Cognac ou Armagnec (hl)"]].sum(axis=0).T.sum().T
autre
# Out:
# /home/keulbunutu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                    Sup vignes cognac - armagniac (ha)  \
# DEPARTEMENTS
# 40 LANDES                                    343.1748
# 47 LOT-ET-GAR                                 28.0906
# 24 DORDOGNE                                   14.3728
# 01 AIN                                         0.0000
# 02 AISNE                                       0.0000
# 03 ALLIER                                      0.0000
# 04 ALPES-HTE-PR                                0.0000
# 05 ALPES-HAUTES                                0.0000
# 06 ALPES-Mmes                                  0.0000
# ...

# %%
top = classement.iloc[:2]
top = top.reset_index()
perfect = top.append(autres.T, ignore_index=True).fillna("AUTRE").set_index("DEPARTEMENTS")
perfect
# Out:
#                  Sup vignes cognac - armagniac (ha)  \
# DEPARTEMENTS
# 16 CHARENTE                              37838.3640
# 17 CHARENTE-MAR                          35614.0841
# AUTRE                                      385.6382
#
#                  Qt Cognac ou Armagnec (hl)
# DEPARTEMENTS
# 16 CHARENTE                      4697139.32
# 17 CHARENTE-MAR                  4591089.05
# AUTRE                              36119.66

# %%
plt.pie(
    # using data total)arrests
    perfect['Sup vignes cognac - armagniac (ha)'],
    # with the labels being officer names
    labels=perfect.index,
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()
# ont remarque que pour Sup vignes cognac - armagniac (ha) c'est les regions de CHARENTE 
# ET CHARENTE-MAR qui ont le plus d'hectar

# %%
plt.pie(
    # using data total)arrests
    perfect['Qt Cognac ou Armagnec (hl)'],
    # with the labels being officer names
    labels=perfect.index,
    startangle=100,
    # with the percent listed as a fraction
    autopct='%1.1f%%', 
    )

# View the plot drop above
plt.axis('equal')
# View the plot
plt.tight_layout()
plt.show()
