# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
pubg = pd.read_csv('publin.csv', sep=",")
pubg
# Out:
#         TV  Radio  Journeaux  Ventes
# 0    230.1   37.8       69.2    22.1
# 1     44.5   39.3       45.1    10.4
# 2     17.2   45.9       69.3     9.3
# 3    151.5   41.3       58.5    18.5
# 4    180.8   10.8       58.4    12.9
# 5      8.7   48.9       75.0     7.2
# 6     57.5   32.8       23.5    11.8
# 7    120.2   19.6       11.6    13.2
# 8      8.6    2.1        1.0     4.8
# 9    199.8    2.6       21.2    10.6
# 10    66.1    5.8       24.2     8.6
# 11   214.7   24.0        4.0    17.4
# 12    23.8   35.1       65.9     9.2
# 13    97.5    7.6        7.2     9.7
# 14   204.1   32.9       46.0    19.0
# 15   195.4   47.7       52.9    22.4
# 16    67.8   36.6      114.0    12.5
# 17   281.4   39.6       55.8    24.4
# 18    69.2   20.5       18.3    11.3
# 19   147.3   23.9       19.1    14.6
# 20   218.4   27.7       53.4    18.0
# 21   237.4    5.1       23.5    12.5
# 22    13.2   15.9       49.6     5.6
# 23   228.3   16.9       26.2    15.5
# ...

# %%
pubg.head()
# Out:
#       TV  Radio  Journeaux  Ventes
# 0  230.1   37.8       69.2    22.1
# 1   44.5   39.3       45.1    10.4
# 2   17.2   45.9       69.3     9.3
# 3  151.5   41.3       58.5    18.5
# 4  180.8   10.8       58.4    12.9

# %%
pubg.dtypes
# Out:
# TV           float64
# Radio        float64
# Journeaux    float64
# Ventes       float64
# dtype: object

# %%
pubg.shape
# Out:
# (200, 4)

# %%
pu = pubg[['TV','Radio']]

# %%
pu.corr()
# Out:
#                  TV     Radio  Journeaux
# TV         1.000000  0.054809   0.056648
# Radio      0.054809  1.000000   0.354104
# Journeaux  0.056648  0.354104   1.000000

# %%
pubg.corr()
# Out:
#                  TV     Radio  Journeaux    Ventes
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Journeaux  0.056648  0.354104   1.000000  0.228299
# Ventes     0.782224  0.576223   0.228299  1.000000

# %%
sns.set(style="ticks", color_codes=True)

sns.pairplot(pubg, x_vars=["TV", "Radio", "Journeaux"],
                        y_vars=["Ventes"], kind = "reg", size = 4)

# %%
z = 'nassim'

# %%
z
# Out:
# 'nassim'

# %%
x = pu

y = pubg[['Ventes']]

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size= 0.2, random_state = 1)

# %%
#lm = LinearRegression().fit(x, y)
#lm.score(x, y)
lm=LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.predict(x_test)
# Out:
# array([[21.75602835],
#        [16.45283   ],
#        [ 7.68498075],
#        [17.89854771],
#        [18.67725322],
#        [23.8001131 ],
#        [16.28958747],
#        [13.36567675],
#        [ 9.13663933],
#        [17.29146113],
#        [14.41976185],
#        [ 9.88105063],
#        [17.33065475],
#        [16.69814917],
#        [15.00680872],
#        [15.48131088],
#        [12.43241041],
#        [17.31064343],
#        [11.16764004],
#        [18.13321062],
#        [ 9.38132296],
#        [12.71353738],
#        [ 8.75011855],
#        [10.5014414 ],
#        [11.37124838],
#        [15.03593604],
#        [ 9.77378461],
#        [19.48694106],
#        [18.32570002],
#        [17.20710464],
#        [21.66189194],
#        [14.55054628],
#        [16.37218182],
#        [12.32883551],
#        [20.02621323],
#        [15.39390999],
#        [13.98341958],
#        [10.03852687],
#        [21.01121113],
#        [ 7.48429727]])

# %%
lm.score(x_test, y_test)
# Out:
# 0.8947344950027067

# %%
plt.figure(figsize=(10,10))
sns.residplot(pu[['TV']], pubg['Ventes'])
plt.show()
plt.figure(figsize=(10,10))
sns.residplot(pu[['Radio']], pubg['Ventes'])
plt.show()
#plt.figure(figsize=(10,10))
#sns.residplot(pu[['Journeaux']], pubg['Ventes'])
#plt.show()

# %%
plt.figure(figsize=(10,10))
sns.regplot(pu[['TV']], pubg['Ventes'])
plt.show()
plt.figure(figsize=(10,10))
sns.regplot(pu[['Radio']], pubg['Ventes'])
plt.show()
#plt.figure(figsize=(10,10))
#sns.regplot(pu[['Journeaux']], pubg['Ventes'])
#plt.show()

# %%
lm.intercept_
# Out:
# array([2.94751504])

# %%
y_pred = lm.predict(x_test)
print(y_pred)
# Out:
# [[21.75602835]
#  [16.45283   ]
#  [ 7.68498075]
#  [17.89854771]
#  [18.67725322]
#  [23.8001131 ]
#  [16.28958747]
#  [13.36567675]
#  [ 9.13663933]
#  [17.29146113]
#  [14.41976185]
#  [ 9.88105063]
#  [17.33065475]
#  [16.69814917]
#  [15.00680872]
#  [15.48131088]
#  [12.43241041]
#  [17.31064343]
#  [11.16764004]
#  [18.13321062]
#  [ 9.38132296]
#  [12.71353738]
#  [ 8.75011855]
#  [10.5014414 ]
#  [11.37124838]
#  [15.03593604]
#  [ 9.77378461]
#  [19.48694106]
#  [18.32570002]
#  [17.20710464]
#  [21.66189194]
#  [14.55054628]
#  [16.37218182]
#  [12.32883551]
#  [20.02621323]
#  [15.39390999]
#  [13.98341958]
#  [10.03852687]
#  [21.01121113]
#  [ 7.48429727]]

# %%
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 1.3982924890777746
